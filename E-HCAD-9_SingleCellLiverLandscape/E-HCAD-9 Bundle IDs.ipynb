# %% [markdown]
# # Bundle ID / Version column filler

# %% [markdown]
# ## 1. Dataset info

# %%
accession_index = 9
project_name = "SingleCellLiverLandscape"

# %%
work_dir = f"E-HCAD-{accession_index}_{project_name}"
accession = f"E-HCAD-{accession_index}"
protocol_accession = f"HCAD{accession_index}"
idf_file_name = f"{accession}.idf.txt"
sdrf_file_name = f"{accession}.sdrf.txt"

# %% [markdown]
# ## 2. Load SDRF

# %%
import pandas as pd
pd.set_option('display.max_columns', 0)
pd.set_option('display.max_rows', 0)

# %%
sdrf = pd.read_csv(sdrf_file_name, sep="\t", keep_default_na=False)

# %%
len(sdrf)
# Out:
# 40

# %%
manifest = pd.read_csv(f"../hca_manifest.tsv", sep="\t", keep_default_na=False)

# %% [markdown]
# ## 3. Select required piece of the manifest

# %%
required_cols = ["bundle_uuid", "bundle_version", "file_name", "sample.biomaterial_core.biomaterial_id"]
manifest_chunk = manifest.loc[manifest['project.project_core.project_short_name'] == project_name][required_cols]

# %% [markdown]
# ## 4. Filter bundle IDs
# Take the earliest versions of the file bundles:
# 1. Sort by bundle version date.
# 2. Drop duplicates.

# %%
manifest_chunk['date'] = pd.to_datetime(manifest_chunk['bundle_version'])

# %%
manifest_chunk['file_part'] = manifest_chunk['file_name'].str.slice(0, -16)

# %%
result = manifest_chunk.sort_values(by='date').drop_duplicates(subset=["file_part"]).sort_values(by=["sample.biomaterial_core.biomaterial_id", "file_part"])

# %%
result.to_csv(f"E-HCAD-9 Bundle IDs.tsv", sep="\t")

# %%
result
# Out:
#                                bundle_uuid             bundle_version  ...                             date             file_part
# 891   c59a8de8-d4f3-424b-b716-06b7152b980a  2019-09-23T173114.106782Z  ... 2019-09-23 17:31:14.106782+00:00          TLH_S11_L001
# 885   c59a8de8-d4f3-424b-b716-06b7152b980a  2019-09-23T173114.106782Z  ... 2019-09-23 17:31:14.106782+00:00          TLH_S11_L002
# 881   c59a8de8-d4f3-424b-b716-06b7152b980a  2019-09-23T173114.106782Z  ... 2019-09-23 17:31:14.106782+00:00          TLH_S11_L003
# 877   c59a8de8-d4f3-424b-b716-06b7152b980a  2019-09-23T173114.106782Z  ... 2019-09-23 17:31:14.106782+00:00          TLH_S11_L004
# 875   c59a8de8-d4f3-424b-b716-06b7152b980a  2019-09-23T173114.106782Z  ... 2019-09-23 17:31:14.106782+00:00          TLH_S11_L005
# 888   c59a8de8-d4f3-424b-b716-06b7152b980a  2019-09-23T173114.106782Z  ... 2019-09-23 17:31:14.106782+00:00          TLH_S11_L006
# 878   c59a8de8-d4f3-424b-b716-06b7152b980a  2019-09-23T173114.106782Z  ... 2019-09-23 17:31:14.106782+00:00          TLH_S11_L007
# 882   c59a8de8-d4f3-424b-b716-06b7152b980a  2019-09-23T173114.106782Z  ... 2019-09-23 17:31:14.106782+00:00          TLH_S11_L008
# 1044  c65efd23-bbc4-459a-ac60-d3cde705193d  2019-09-23T173114.107641Z  ... 2019-09-23 17:31:14.107641+00:00           TLH_S3_L001
# 602   c65efd23-bbc4-459a-ac60-d3cde705193d  2019-09-23T173114.107641Z  ... 2019-09-23 17:31:14.107641+00:00           TLH_S3_L002
# 1115  c65efd23-bbc4-459a-ac60-d3cde705193d  2019-09-23T173114.107641Z  ... 2019-09-23 17:31:14.107641+00:00           TLH_S3_L003
# 599   c65efd23-bbc4-459a-ac60-d3cde705193d  2019-09-23T173114.107641Z  ... 2019-09-23 17:31:14.107641+00:00           TLH_S3_L004
# 1042  c65efd23-bbc4-459a-ac60-d3cde705193d  2019-09-23T173114.107641Z  ... 2019-09-23 17:31:14.107641+00:00           TLH_S3_L005
# 1040  c65efd23-bbc4-459a-ac60-d3cde705193d  2019-09-23T173114.107641Z  ... 2019-09-23 17:31:14.107641+00:00           TLH_S3_L006
# 593   c65efd23-bbc4-459a-ac60-d3cde705193d  2019-09-23T173114.107641Z  ... 2019-09-23 17:31:14.107641+00:00           TLH_S3_L007
# 1036  c65efd23-bbc4-459a-ac60-d3cde705193d  2019-09-23T173114.107641Z  ... 2019-09-23 17:31:14.107641+00:00           TLH_S3_L008
# 948   fb2ae8b7-06b0-4881-ad9f-1f37255b91b6  2019-09-23T173114.107225Z  ... 2019-09-23 17:31:14.107225+00:00   TLH_June_29_S1_L001
# 957   fb2ae8b7-06b0-4881-ad9f-1f37255b91b6  2019-09-23T173114.107225Z  ... 2019-09-23 17:31:14.107225+00:00   TLH_June_29_S1_L002
# 951   fb2ae8b7-06b0-4881-ad9f-1f37255b91b6  2019-09-23T173114.107225Z  ... 2019-09-23 17:31:14.107225+00:00   TLH_June_29_S1_L003
# ...                                    ...                        ...  ...                              ...                   ...
# 1238  fb2ae8b7-06b0-4881-ad9f-1f37255b91b6  2019-09-23T173114.107225Z  ... 2019-09-23 17:31:14.107225+00:00   TLH_June_29_S1_L006
# 959   fb2ae8b7-06b0-4881-ad9f-1f37255b91b6  2019-09-23T173114.107225Z  ... 2019-09-23 17:31:14.107225+00:00   TLH_June_29_S1_L007
# 954   fb2ae8b7-06b0-4881-ad9f-1f37255b91b6  2019-09-23T173114.107225Z  ... 2019-09-23 17:31:14.107225+00:00   TLH_June_29_S1_L008
# 1229  fd7a46db-1e90-4bfd-8e70-a77baa01faa5  2019-09-23T173114.106310Z  ... 2019-09-23 17:31:14.106310+00:00   TLH_July_13_S6_L001
# 1222  fd7a46db-1e90-4bfd-8e70-a77baa01faa5  2019-09-23T173114.106310Z  ... 2019-09-23 17:31:14.106310+00:00   TLH_July_13_S6_L002
# 1272  fd7a46db-1e90-4bfd-8e70-a77baa01faa5  2019-09-23T173114.106310Z  ... 2019-09-23 17:31:14.106310+00:00   TLH_July_13_S6_L003
# 1213  fd7a46db-1e90-4bfd-8e70-a77baa01faa5  2019-09-23T173114.106310Z  ... 2019-09-23 17:31:14.106310+00:00   TLH_July_13_S6_L004
# 1231  fd7a46db-1e90-4bfd-8e70-a77baa01faa5  2019-09-23T173114.106310Z  ... 2019-09-23 17:31:14.106310+00:00   TLH_July_13_S6_L005
# 1218  fd7a46db-1e90-4bfd-8e70-a77baa01faa5  2019-09-23T173114.106310Z  ... 2019-09-23 17:31:14.106310+00:00   TLH_July_13_S6_L006
# 1219  fd7a46db-1e90-4bfd-8e70-a77baa01faa5  2019-09-23T173114.106310Z  ... 2019-09-23 17:31:14.106310+00:00   TLH_July_13_S6_L007
# 1224  fd7a46db-1e90-4bfd-8e70-a77baa01faa5  2019-09-23T173114.106310Z  ... 2019-09-23 17:31:14.106310+00:00   TLH_July_13_S6_L008
# 991   be9f2d04-77ee-4f59-a0f7-f0b58034cf8c  2019-09-23T173114.105576Z  ... 2019-09-23 17:31:14.105576+00:00  TLH_2nd_wash_S3_L001
# 838   be9f2d04-77ee-4f59-a0f7-f0b58034cf8c  2019-09-23T173114.105576Z  ... 2019-09-23 17:31:14.105576+00:00  TLH_2nd_wash_S3_L002
# 841   be9f2d04-77ee-4f59-a0f7-f0b58034cf8c  2019-09-23T173114.105576Z  ... 2019-09-23 17:31:14.105576+00:00  TLH_2nd_wash_S3_L003
# 1067  be9f2d04-77ee-4f59-a0f7-f0b58034cf8c  2019-09-23T173114.105576Z  ... 2019-09-23 17:31:14.105576+00:00  TLH_2nd_wash_S3_L004
# 800   be9f2d04-77ee-4f59-a0f7-f0b58034cf8c  2019-09-23T173114.105576Z  ... 2019-09-23 17:31:14.105576+00:00  TLH_2nd_wash_S3_L005
# 794   be9f2d04-77ee-4f59-a0f7-f0b58034cf8c  2019-09-23T173114.105576Z  ... 2019-09-23 17:31:14.105576+00:00  TLH_2nd_wash_S3_L006
# 1004  be9f2d04-77ee-4f59-a0f7-f0b58034cf8c  2019-09-23T173114.105576Z  ... 2019-09-23 17:31:14.105576+00:00  TLH_2nd_wash_S3_L007
# 1142  be9f2d04-77ee-4f59-a0f7-f0b58034cf8c  2019-09-23T173114.105576Z  ... 2019-09-23 17:31:14.105576+00:00  TLH_2nd_wash_S3_L008
#
# [40 rows x 6 columns]
