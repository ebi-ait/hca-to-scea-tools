# %% [markdown]
# # Bundle ID / Version column filler

# %% [markdown]
# ## 1. Dataset info

# %%
accession_index = 9
project_name = "SingleCellLiverLandscape"

# %%
work_dir = f"E-HCAD-{accession_index}_{project_name}"
accession = f"E-HCAD-{accession_index}"
protocol_accession = f"HCAD{accession_index}"
idf_file_name = f"{accession}.idf.txt"
sdrf_file_name = f"{accession}.sdrf.txt"

# %% [markdown]
# ## 2. Load SDRF

# %%
import pandas as pd
pd.set_option('display.max_columns', 0)
pd.set_option('display.max_rows', 0)

# %%
sdrf = pd.read_csv(sdrf_file_name, sep="\t", keep_default_na=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fdf596858b32> in <module>
# ----> 1 sdrf = pd.read_csv(sdrf_file_name, sep="\t", keep_default_na=False)
#
# NameError: name 'pd' is not defined

# %%
manifest = pd.read_csv(f"../hca_manifest.tsv", sep="\t", keep_default_na=False)

# %% [markdown]
# ## 3. Select required piece of the manifest

# %%
required_cols = ["bundle_uuid", "bundle_version", "file_name", "sample.biomaterial_core.biomaterial_id"]
manifest_chunk = manifest.loc[manifest['project.project_core.project_short_name'] == project_name][required_cols]

# %% [markdown]
# ## 4. Filter bundle IDs
# Take the earliest versions of the file bundles:
# 1. Sort by bundle version date.
# 2. Drop duplicates.

# %%
manifest_chunk['file_part'] = manifest_chunk['file_name'].str.slice(0, -16)

# %%
manifest_chunk = manifest_chunk.drop_duplicates(subset=['file_part'])

# %%
manifest_chunk['date'] = pd.to_datetime(manifest_chunk['bundle_version'])
# Out:
# <ipython-input-20-98bb69319139>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   manifest_chunk['date'] = pd.to_datetime(manifest_chunk['bundle_version'])

# %%
manifest_chunk.sort_values(by='bundle_version').sort_values(by=["sample.biomaterial_core.biomaterial_id", "file_part"])
# Out:
#                                bundle_uuid             bundle_version  ...                             date             file_part
# 753   2f62f508-6503-4c2e-a714-8298f55bdaa2  2019-09-26T064657.900169Z  ... 2019-09-26 06:46:57.900169+00:00          TLH_S11_L001
# 755   c59a8de8-d4f3-424b-b716-06b7152b980a  2019-09-23T173114.106782Z  ... 2019-09-23 17:31:14.106782+00:00          TLH_S11_L002
# 733   2f62f508-6503-4c2e-a714-8298f55bdaa2  2019-09-26T064657.900169Z  ... 2019-09-26 06:46:57.900169+00:00          TLH_S11_L003
# 737   2f62f508-6503-4c2e-a714-8298f55bdaa2  2019-09-26T064657.900169Z  ... 2019-09-26 06:46:57.900169+00:00          TLH_S11_L004
# 739   2f62f508-6503-4c2e-a714-8298f55bdaa2  2019-09-26T064657.900169Z  ... 2019-09-26 06:46:57.900169+00:00          TLH_S11_L005
# 735   2f62f508-6503-4c2e-a714-8298f55bdaa2  2019-09-26T064657.900169Z  ... 2019-09-26 06:46:57.900169+00:00          TLH_S11_L006
# 742   2f62f508-6503-4c2e-a714-8298f55bdaa2  2019-09-26T064657.900169Z  ... 2019-09-26 06:46:57.900169+00:00          TLH_S11_L007
# 731   c59a8de8-d4f3-424b-b716-06b7152b980a  2019-09-23T173114.106782Z  ... 2019-09-23 17:31:14.106782+00:00          TLH_S11_L008
# 603   56cce395-634e-4c53-976c-931727d22dfa  2019-09-26T074759.713933Z  ... 2019-09-26 07:47:59.713933+00:00           TLH_S3_L001
# 601   56cce395-634e-4c53-976c-931727d22dfa  2019-09-26T074759.713933Z  ... 2019-09-26 07:47:59.713933+00:00           TLH_S3_L002
# 670   56cce395-634e-4c53-976c-931727d22dfa  2019-09-26T074759.713933Z  ... 2019-09-26 07:47:59.713933+00:00           TLH_S3_L003
# 598   56cce395-634e-4c53-976c-931727d22dfa  2019-09-26T074759.713933Z  ... 2019-09-26 07:47:59.713933+00:00           TLH_S3_L004
# 596   56cce395-634e-4c53-976c-931727d22dfa  2019-09-26T074759.713933Z  ... 2019-09-26 07:47:59.713933+00:00           TLH_S3_L005
# 664   56cce395-634e-4c53-976c-931727d22dfa  2019-09-26T074759.713933Z  ... 2019-09-26 07:47:59.713933+00:00           TLH_S3_L006
# 592   56cce395-634e-4c53-976c-931727d22dfa  2019-09-26T074759.713933Z  ... 2019-09-26 07:47:59.713933+00:00           TLH_S3_L007
# 594   56cce395-634e-4c53-976c-931727d22dfa  2019-09-26T074759.713933Z  ... 2019-09-26 07:47:59.713933+00:00           TLH_S3_L008
# 948   fb2ae8b7-06b0-4881-ad9f-1f37255b91b6  2019-09-23T173114.107225Z  ... 2019-09-23 17:31:14.107225+00:00   TLH_June_29_S1_